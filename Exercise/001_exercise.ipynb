# %% [markdown]
# # First exercise for the etl course

# %% [markdown]
# ## Importing the datasets

# %%
import yaml
import psycopg2
from psycopg2 import sql
from sqlalchemy import create_engine, text
import pandas as pd
import os

# %%
def load_config(file_path="config.yaml"):
    with open(file_path,"r") as file:
        return yaml.safe_load(file)

# %% [markdown]
# Loading the dataset from file in local, and also checking the lenght of characters for the creation of the database

# %%
print(os.getcwd())
dataset = pd.read_csv("dataset/candidates.csv",sep=";")
for column in dataset.columns:
    max_len = 0
    for i in dataset[column].astype(str):
        if len(i) > max_len:
            max_len = len(i)
    print(f"Max length in column '{column}': {max_len}")
# Out:
# /Users/santiagoaristizabal/Learning/python/etl_course/Exercise
# Max length in column 'First Name': 11
# Max length in column 'Last Name': 13
# Max length in column 'Email': 36
# Max length in column 'Application Date': 10
# Max length in column 'Country': 51
# Max length in column 'YOE': 2
# Max length in column 'Seniority': 9
# Max length in column 'Technology': 39
# Max length in column 'Code Challenge Score': 2
# Max length in column 'Technical Interview Score': 2

# %% [markdown]
# Changing the names of the file to be able to connect it to the database created

# %%
dataset.rename(columns={
    "First Name":"name",
    "Last Name":"lastname",
    "Email":"email",
    "Application Date":"applicationdate",
    "Country":"country",
    "YOE":"yoe",
    "Seniority":"seniority",
    "Technology":"technology",
    "Code Challenge Score":"codescore",
    "Technical Interview Score":"interviewscore",
}, inplace=True)

# %%
config = load_config()
db_config = config["database"]

db_user = db_config["user"]
db_password = db_config["password"]
db_host = db_config["host"]
db_port = db_config["port"]
db_name = db_config["name"]

conn = psycopg2.connect(
    dbname="postgres",
    user=db_user,
    password = db_password,
    host = db_host,
    port = db_port
)
conn.autocommit = True

# %%
try:
    with conn.cursor() as cur:
        cur.execute(sql.SQL("CREATE DATABASE {}").format(sql.Identifier(db_name)))
        print(f"Base de datos '{db_name}' creada exitosamente")
except psycopg2.errors.DuplicateDatabase:
    print(f"La base de datos '{db_name}' ya existe.")
finally:
    conn.close()
# Out:
# La base de datos 'candidates_etl_2' ya existe.

# %% [markdown]
# Creating the database

# %%
engine = create_engine(f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")

with engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS candidates_etl_2 (
            id SERIAL PRIMARY KEY,
            name VARCHAR(50),
            lastname VARCHAR(50),
            email VARCHAR(50),
            applicationdate DATE,
            country VARCHAR(100),
            yoe INT,
            seniority VARCHAR(20),
            technology VARCHAR(50),
            codescore INT,
            interviewscore INT           
        );
    """))
    conn.commit()
    print(f"{db_name} creada exitosamente")
# Out:
# candidates_etl_2 creada exitosamente

# %% [markdown]
# Loading the csv to the postgres database

# %%
with engine.connect() as conn:
    dataset.to_sql("candidates_etl_2",con=engine, if_exists="append", index=False)
print("Base de datos montada a sql")
# Out:
# Base de datos montada a sql

# %% [markdown]
# Loading the 10 first data from the database

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM candidates_etl_2;"))
    rows = result.fetchall()

print("Datos en 'candidates_etl_2' :")
num = 0
for row in rows:
    print(row)
    num += 1
    if num > 10:
        break
# Out:
# Datos en 'candidates_etl_2' :
# (1, 'Bernadette', 'Langworth', 'leonard91@yahoo.com', datetime.date(2021, 2, 26), 'Norway', 2, 'Intern', 'Data Engineer', 3, 3)
# (2, 'Camryn', 'Reynolds', 'zelda56@hotmail.com', datetime.date(2021, 9, 9), 'Panama', 10, 'Intern', 'Data Engineer', 2, 10)
# (3, 'Larue', 'Spinka', 'okey_schultz41@gmail.com', datetime.date(2020, 4, 14), 'Belarus', 4, 'Mid-Level', 'Client Success', 10, 9)
# (4, 'Arch', 'Spinka', 'elvera_kulas@yahoo.com', datetime.date(2020, 10, 1), 'Eritrea', 25, 'Trainee', 'QA Manual', 7, 1)
# (5, 'Larue', 'Altenwerth', 'minnie.gislason@gmail.com', datetime.date(2020, 5, 20), 'Myanmar', 13, 'Mid-Level', 'Social Media Community Management', 9, 7)
# (6, 'Alec', 'Abbott', 'juanita_hansen@gmail.com', datetime.date(2019, 8, 17), 'Zimbabwe', 8, 'Junior', 'Adobe Experience Manager', 2, 9)
# (7, 'Allison', 'Jacobs', 'alba_rolfson27@yahoo.com', datetime.date(2018, 5, 18), 'Wallis and Futuna', 19, 'Trainee', 'Sales', 2, 9)
# (8, 'Nya', 'Skiles', 'madisen.zulauf@gmail.com', datetime.date(2021, 12, 9), 'Myanmar', 1, 'Lead', 'Mulesoft', 2, 5)
# (9, 'Mose', 'Lakin', 'dale_murazik@hotmail.com', datetime.date(2018, 3, 13), 'Italy', 18, 'Lead', 'Social Media Community Management', 7, 10)
# (10, 'Terrance', 'Zieme', 'dustin31@hotmail.com', datetime.date(2022, 4, 8), 'Timor-Leste', 25, 'Lead', 'DevOps', 2, 0)
# (11, 'Aiyana', 'Goodwin', 'vallie.damore@yahoo.com', datetime.date(2019, 9, 22), 'Armenia', 24, 'Intern', 'Development - CMS Backend', 4, 9)

# %%
with engine.connect() as conn:
    raw_df = pd.read_sql("SELECT * FROM candidates_etl_2", conn)

# %%
raw_df.head()
# Out:
#    id        name    lastname                      email applicationdate  \
# 0   1  Bernadette   Langworth        leonard91@yahoo.com      2021-02-26
# 1   2      Camryn    Reynolds        zelda56@hotmail.com      2021-09-09
# 2   3       Larue      Spinka   okey_schultz41@gmail.com      2020-04-14
# 3   4        Arch      Spinka     elvera_kulas@yahoo.com      2020-10-01
# 4   5       Larue  Altenwerth  minnie.gislason@gmail.com      2020-05-20
#
#    country  yoe  seniority                         technology  codescore  \
# 0   Norway    2     Intern                      Data Engineer          3
# 1   Panama   10     Intern                      Data Engineer          2
# 2  Belarus    4  Mid-Level                     Client Success         10
# 3  Eritrea   25    Trainee                          QA Manual          7
# 4  Myanmar   13  Mid-Level  Social Media Community Management          9
#
#    interviewscore
# 0               3
# 1              10
# 2               9
# 3               1
# 4               7

# %% [markdown]
# Creating the hired column

# %%
df_transform = raw_df.copy()
df_transform['hired'] = df_transform.apply(
    lambda columna: "YES" if columna["codescore"] >= 7 and columna["interviewscore"] >= 7 else "NO",axis=1
)

df_transform.head()
# Out:
#    id        name    lastname                      email applicationdate  \
# 0   1  Bernadette   Langworth        leonard91@yahoo.com      2021-02-26
# 1   2      Camryn    Reynolds        zelda56@hotmail.com      2021-09-09
# 2   3       Larue      Spinka   okey_schultz41@gmail.com      2020-04-14
# 3   4        Arch      Spinka     elvera_kulas@yahoo.com      2020-10-01
# 4   5       Larue  Altenwerth  minnie.gislason@gmail.com      2020-05-20
#
#    country  yoe  seniority                         technology  codescore  \
# 0   Norway    2     Intern                      Data Engineer          3
# 1   Panama   10     Intern                      Data Engineer          2
# 2  Belarus    4  Mid-Level                     Client Success         10
# 3  Eritrea   25    Trainee                          QA Manual          7
# 4  Myanmar   13  Mid-Level  Social Media Community Management          9
#
#    interviewscore hired
# 0               3    NO
# 1              10    NO
# 2               9   YES
# 3               1    NO
# 4               7   YES

# %% [markdown]
# creating the new database with the hired column

# %%
with engine.connect() as conn:
    conn.execute(text("""
    CREATE TABLE IF NOT EXISTS candidates_etl_transformed (
            id SERIAL PRIMARY KEY,
            name VARCHAR(50),
            lastname VARCHAR(50),
            email VARCHAR(50),
            applicationdate DATE,
            country VARCHAR(100),
            yoe INT,
            seniority VARCHAR(20),
            technology VARCHAR(50),
            codescore INT,
            interviewscore INT,
            hired VARCHAR(5)       
        );
"""))

# %% [markdown]
# Loading the new database

# %%
with engine.connect() as conn:
    df_transform.to_sql("candidates_etl_transformed", con=engine, if_exists="append", index=False)

print("Transformed data stored successfully in 'candidates_etl_transformed'.")
# Out:
# Transformed data stored successfully in 'candidates_etl_transformed'.

# %%
with engine.connect() as conn:
    db_transformed_df = pd.read_sql("SELECT * FROM candidates_etl_transformed", conn)
    
db_transformed_df
# Out:
#           id        name    lastname                       email  \
# 0          1  Bernadette   Langworth         leonard91@yahoo.com
# 1          2      Camryn    Reynolds         zelda56@hotmail.com
# 2          3       Larue      Spinka    okey_schultz41@gmail.com
# 3          4        Arch      Spinka      elvera_kulas@yahoo.com
# 4          5       Larue  Altenwerth   minnie.gislason@gmail.com
# ...      ...         ...         ...                         ...
# 49995  49996     Bethany     Shields  rocky_mitchell@hotmail.com
# 49996  49997         Era  Swaniawski    dolores.roob@hotmail.com
# 49997  49998      Martin       Lakin   savanah.stracke@gmail.com
# 49998  49999       Aliya   Abernathy  vivienne.fritsch@yahoo.com
# 49999  50000     Coleman      Wisozk   abigayle.crooks@yahoo.com
#
#       applicationdate             country  yoe  seniority  \
# 0          2021-02-26              Norway    2     Intern
# 1          2021-09-09              Panama   10     Intern
# 2          2020-04-14             Belarus    4  Mid-Level
# 3          2020-10-01             Eritrea   25    Trainee
# 4          2020-05-20             Myanmar   13  Mid-Level
# ...               ...                 ...  ...        ...
# 49995      2022-01-09  Dominican Republic   27    Trainee
# 49996      2020-06-02             Morocco   21       Lead
# 49997      2018-12-15              Uganda   20    Trainee
# 49998      2020-05-30      Czech Republic   20     Senior
# 49999      2022-06-13               Palau   15     Intern
#
#                               technology  codescore  interviewscore hired
# 0                          Data Engineer          3               3    NO
# 1                          Data Engineer          2              10    NO
# 2                         Client Success         10               9   YES
# 3                              QA Manual          7               1    NO
# 4      Social Media Community Management          9               7   YES
# ...                                  ...        ...             ...   ...
# 49995                           Security          2               1    NO
# 49996                   Game Development          1               2    NO
# 49997              System Administration          6               1    NO
# 49998            Database Administration          0               0    NO
# 49999                           Mulesoft          3               1    NO
#
# [50000 rows x 12 columns]
